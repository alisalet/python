# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,10,100)
y=np.sin(x)
z=np.cos(x)
plt.plot(x,y,label='sin(x)',color='#40a6e6')
plt.plot(x,z,label='cos(x)',color='#f060c9')
plt.title('Графики sin(x) и cos(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %%
x=np.random.normal(0,1,1000)

plt.hist(x,bins=20,color='#40a6e6',edgecolor='#3c7ee8')
plt.title('Гистограмма нормального распределения')
plt.xlabel('Значения')
plt.ylabel('Данные')
plt.show()

# %%
x=np.random.randint(1,11,size=(5,5))

average=np.mean(x)
max=np.max(x)
min=np.min(x)
columns=np.sum(x,axis=0)

print(f'Матрица:\n{x}')
print(f'\nСреднее значение: {average}')
print(f'\nМаксимальный элемент: {max}')
print(f'\nМинимальное значение: {min}')
print(f'\nСумма по столбцам: {columns}')
# Out:
# Матрица:
# [[ 9  1  4 10  4]
#  [ 6  1  5  9  7]
#  [ 3  6  2  2  3]
#  [ 9  4  4  9  9]
#  [ 1  8  8  8  6]]
#
# Среднее значение: 5.52
#
# Максимальный элемент: 10
#
# Минимальное значение: 1
#
# Сумма по столбцам: [28 20 23 38 29]

# %%
plt.imshow(x,cmap='plasma')
plt.colorbar(label='Значения')
#добавление значений матрицы в ячейки
for i in range(x.shape[0]):
    for j in range(x.shape[1]):
        plt.text(j,i,x[i, j],ha='center',va='center',fontsize=15)
plt.title('Тепловая карта матрицы')
plt.show()

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,3,1)
x=np.linspace(-5,5,100)
y=x**2
plt.plot(x,y,label='y=x^2',color='#f060c9')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Парабола')
plt.grid()
plt.legend()

plt.subplot(1,3,2)
random_x=np.random.randint(1,11,20)
random_y=np.random.randint(1,11,20)
plt.scatter(random_x,random_y,color='#b66ef5')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Случайные точки')

plt.subplot(1,3,3)
categories=['A','B','C']
values=[3,7,2]
plt.bar(categories,values,color='#40a6e6')
plt.xlabel('Категории')
plt.ylabel('Данные')
plt.title('Столбчатая диаграмма')

plt.show()
